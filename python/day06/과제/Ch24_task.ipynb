# %% [markdown]
# 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %%
def print_info(*, name, age, gender) :
    print(f'이름 : {name}')
    print(f'나이 : {age}')
    print(f'성별 : {gender}')
print_info(name='연우', age=20, gender= '남')
# Out:
# 이름 : 연우
# 나이 : 20
# 성별 : 남
